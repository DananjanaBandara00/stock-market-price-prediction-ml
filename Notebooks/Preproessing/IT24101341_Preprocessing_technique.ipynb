# %%
import pandas as pd
import os

# === Paths ===
input_path = r"C:\Users\pulina\Desktop\2025-Y2-S1-MLB-B6G2-01\results\outputs\IT24101357.xlsx"
output_path = r"C:\Users\pulina\Desktop\2025-Y2-S1-MLB-B6G2-01\results\outputs\IT24101341.xlsx"

df = pd.read_excel(input_path, index_col="Date")

# Example: removing duplicates
df = df.drop_duplicates()

df.to_excel(output_path)
print("Missing values after:\n", df.isna().sum())
print(f" Step Done → {output_path}")
# Out:
# Missing values after:
#  Open           0
# High           0
# Low            0
# Close*         0
# Adj Close**    0
# Volume         0
# dtype: int64
#  Step Done → C:\Users\pulina\Desktop\2025-Y2-S1-MLB-B6G2-01\results\outputs\IT24101341.xlsx
