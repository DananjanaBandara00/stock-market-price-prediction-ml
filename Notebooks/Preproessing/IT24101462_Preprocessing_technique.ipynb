# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# === Paths ===
input_path = r"C:\Users\pulina\Desktop\2025-Y2-S1-MLB-B6G2-01\results\outputs\IT24101341.xlsx"
output_path = r"C:\Users\pulina\Desktop\2025-Y2-S1-MLB-B6G2-01\results\outputs\IT24101462.xlsx"

# === Load Dataset ===
df = pd.read_excel(input_path, index_col="Date")

# Example: create new feature
df["Log_Close"] = np.log(df["Adj Close**"])

# === Save Output ===
df.to_excel(output_path)
print(f" Step Done → {output_path}")

plt.boxplot(df['Volume'])
plt.title("Boxplot of Volume After Outlier Removal")
plt.show()
print("Step 3 done.")
# Out:
#  Step Done → C:\Users\pulina\Desktop\2025-Y2-S1-MLB-B6G2-01\results\outputs\IT24101462.xlsx
# Step 3 done.
